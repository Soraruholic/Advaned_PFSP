# %%
import math
import random
import numpy as np
from datetime import datetime, timedelta
from solver import Solver
from population import Population
import localSearch
from GeneticAlgorithm import GeneticAlgorithm
from Climb import Climb
from SimulatedAnnealing import SimulatedAnnealing
from chromes import initializeChromes, selectChromes, crossChromes, muteChromes
import loadData
import NEH
import selection
import chromes
from matplotlib import pyplot as plt
import seaborn as sns
import pandas as pd
from scipy import stats
from scipy.stats import norm, skew
color = sns.color_palette()
sns.set_style ('darkgrid')
rc = {'font.sans-serif': 'SimHei',
          'axes.unicode_minus': False}
import warnings
def ignore_warn(*args, **kwargs):
    pass
warnings.warn = ignore_warn
err_up = list()
err_low = list()
size_n = list()
size_m = list()
def ex2():
    instances, up , low = loadData.dataLoading ("vrf_small")
    for index, instance in enumerate(instances):
        ig = IteratedGreedy(data = instance)
        
        ig.eval(20000)
        size_n.append (instance.shape[0])
        size_m.append (instance.shape[1])
        err_up.append ((ig.best_pop.best_makespan - up[index]) / up[index])
        err_low.append ((ig.best_pop.best_makespan - low[index]) / low[index])
        print (index, ig.iterations)
        #print("Best makespan", ig.best_solver.makespan, ig.iterations)
        #print("Job permutation:", ig.best_solver.permutation)
    ERR_up = np.array (err_up)
    sns.distplot (err_up, fit = norm)
    (mu, sigma) = norm.fit (ERR_up)
    print ('\n mu = {:.2f} and sigma = {:.2f}\n'.format (mu, sigma))
    plt.legend (['Normal dist. ($\mu$ {:.2f} and $\sigma=$ {:.2f})'.format (mu, sigma)], loc = 'best')
    plt.ylabel ('Frequency', fontproperties='SimHei')
    plt.title ('Error of UP', fontproperties='SimHei')

    fig = plt.figure()
    res = stats.probplot (ERR_up, plot = plt)
    plt.show ()
    ERR_low = np.array (err_low)
    sns.distplot (ERR_low, fit = norm)
    (mu, sigma) = norm.fit (ERR_low)
    print ('\n mu = {:.2f} and sigma = {:.2f}\n'.format (mu, sigma))
    plt.legend (['Normal dist. ($\mu$ {:.2f} and $\sigma=$ {:.2f})'.format (mu, sigma)], loc = 'best')
    plt.ylabel ('Frequency', fontproperties='SimHei')
    plt.title ('Error of LOW', fontproperties='SimHei')

    fig = plt.figure()
    res = stats.probplot (ERR_low, plot = plt)
    plt.show ()
    print (len(err_up), len(err_low), len(size_n), len(size_m))
    data = pd.DataFrame ({'err_up': err_up, 'err_low' : err_low, 'n' : size_n, 'm' : size_m})
    data.to_csv ('results/GA_vrf_small_MG10000_P30_CR80_MR15_RT20S.csv')

# %%
import math
import random
import numpy as np
from datetime import datetime, timedelta
from solver import Solver
from population import Population
import localSearch
from localSearch import localSearchPop
from GeneticAlgorithm import GeneticAlgorithm
from Climb import Climb
from SimulatedAnnealing import SimulatedAnnealing
from chromes import initializeChromes, selectChromes, crossChromes, muteChromes
import loadData
import NEH
import selection
import chromes
from matplotlib import pyplot as plt
import seaborn as sns
import pandas as pd
from scipy import stats
from scipy.stats import norm, skew
color = sns.color_palette()
sns.set_style ('darkgrid')
rc = {'font.sans-serif': 'SimHei',
          'axes.unicode_minus': False}
import warnings
def ignore_warn(*args, **kwargs):
    pass
warnings.warn = ignore_warn

def ex3():
    err_up = list()
    err_low = list()
    size_n = list()
    size_m = list()
    instances, up , low = loadData.dataLoading ("vrf_small")
    for index, instance in enumerate(instances):
        ig = IteratedGreedy(data = instance)
        ig.local_search = True
        ig.tie_breaking = True
        ig.eval(40000)
        size_n.append (instance.shape[0])
        size_m.append (instance.shape[1])
        err_up.append ((ig.best_solver.makespan - up[index]) / up[index])
        err_low.append ((ig.best_solver.makespan - low[index]) / low[index])
        print (index, ig.iterations)
        #print("Best makespan", ig.best_solver.makespan, ig.iterations)
        #print("Job permutation:", ig.best_solver.permutation)
    ERR_up = np.array (err_up)
    sns.distplot (err_up, fit = norm)
    (mu, sigma) = norm.fit (ERR_up)
    print ('\n mu = {:.2f} and sigma = {:.2f}\n'.format (mu, sigma))
    plt.legend (['Normal dist. ($\mu$ {:.2f} and $\sigma=$ {:.2f})'.format (mu, sigma)], loc = 'best')
    plt.ylabel ('Frequency', fontproperties='SimHei')
    plt.title ('Error of UP', fontproperties='SimHei')

    fig = plt.figure()
    res = stats.probplot (ERR_up, plot = plt)
    plt.show ()
    ERR_low = np.array (err_low)
    sns.distplot (ERR_low, fit = norm)
    (mu, sigma) = norm.fit (ERR_low)
    print ('\n mu = {:.2f} and sigma = {:.2f}\n'.format (mu, sigma))
    plt.legend (['Normal dist. ($\mu$ {:.2f} and $\sigma=$ {:.2f})'.format (mu, sigma)], loc = 'best')
    plt.ylabel ('Frequency', fontproperties='SimHei')
    plt.title ('Error of LOW', fontproperties='SimHei')

    fig = plt.figure()
    res = stats.probplot (ERR_low, plot = plt)
    plt.show ()
    print (len(err_up), len(err_low), len(size_n), len(size_m))
    data = pd.DataFrame ({'err_up': err_up, 'err_low' : err_low, 'n' : size_n, 'm' : size_m})
    data.to_csv ('results/SA_NOLS_vrf_small_ML1e5_IPE500_RT40S.csv')

# %%
import math
import random
import numpy as np
from datetime import datetime, timedelta
from solver import Solver
from population import Population
import localSearch
from GeneticAlgorithm import GeneticAlgorithm
from Climb import Climb
from SimulatedAnnealing import SimulatedAnnealing
from chromes import initializeChromes, selectChromes, crossChromes, muteChromes
import loadData
import NEH
import selection
import chromes
from matplotlib import pyplot as plt
import seaborn as sns
import pandas as pd
from scipy import stats
from scipy.stats import norm, skew
color = sns.color_palette()
sns.set_style ('darkgrid')
rc = {'font.sans-serif': 'SimHei',
          'axes.unicode_minus': False}
import warnings
def ignore_warn(*args, **kwargs):
    pass
warnings.warn = ignore_warn
err_up = list()
err_low = list()
size_n = list()
size_m = list()
def ex4():
    instances, up , low = loadData.dataLoading ("vrf_large")
    for index, instance in enumerate(instances):
        ig = SimulatedAnnealing(data = instance)
        ig.local_search = False
        ig.tie_breaking = True
        ig.max_loop = 100000
        ig.eval(40000)
        size_n.append (instance.shape[0])
        size_m.append (instance.shape[1])
        err_up.append ((ig.best_solver.makespan - up[index]) / up[index])
        err_low.append ((ig.best_solver.makespan - low[index]) / low[index])
        print (index, ig.iterations)
        #print("Best makespan", ig.best_solver.makespan, ig.iterations)
        #print("Job permutation:", ig.best_solver.permutation)
    ERR_up = np.array (err_up)
    sns.distplot (err_up, fit = norm)
    (mu, sigma) = norm.fit (ERR_up)
    print ('\n mu = {:.2f} and sigma = {:.2f}\n'.format (mu, sigma))
    plt.legend (['Normal dist. ($\mu$ {:.2f} and $\sigma=$ {:.2f})'.format (mu, sigma)], loc = 'best')
    plt.ylabel ('Frequency', fontproperties='SimHei')
    plt.title ('Error of UP', fontproperties='SimHei')

    fig = plt.figure()
    res = stats.probplot (ERR_up, plot = plt)
    plt.show ()
    ERR_low = np.array (err_low)
    sns.distplot (ERR_low, fit = norm)
    (mu, sigma) = norm.fit (ERR_low)
    print ('\n mu = {:.2f} and sigma = {:.2f}\n'.format (mu, sigma))
    plt.legend (['Normal dist. ($\mu$ {:.2f} and $\sigma=$ {:.2f})'.format (mu, sigma)], loc = 'best')
    plt.ylabel ('Frequency', fontproperties='SimHei')
    plt.title ('Error of LOW', fontproperties='SimHei')

    fig = plt.figure()
    res = stats.probplot (ERR_low, plot = plt)
    plt.show ()
    print (len(err_up), len(err_low), len(size_n), len(size_m))
    data = pd.DataFrame ({'err_up': err_up, 'err_low' : err_low, 'n' : size_n, 'm' : size_m})
    data.to_csv ('results/SA_NOLS_vrf_large_MG1e5_IPE500_RT40S.csv')

# %%
import math
import random
import numpy as np
from datetime import datetime, timedelta
from solver import Solver
from population import Population
import localSearch
from GeneticAlgorithm import GeneticAlgorithm
from Climb import Climb
from SimulatedAnnealing import SimulatedAnnealing
from chromes import initializeChromes, selectChromes, crossChromes, muteChromes
import loadData
import NEH
import selection
import chromes
from matplotlib import pyplot as plt
import seaborn as sns
import pandas as pd
from scipy import stats
from scipy.stats import norm, skew
color = sns.color_palette()
sns.set_style ('darkgrid')
rc = {'font.sans-serif': 'SimHei',
          'axes.unicode_minus': False}
import warnings
def ignore_warn(*args, **kwargs):
    pass
warnings.warn = ignore_warn
err_up = list()
err_low = list()
size_n = list()
size_m = list()
def ex5():
    instances, up , low = loadData.dataLoading ("vrf_small")
    for index, instance in enumerate(instances):
        ig = GeneticAlgorithm(data = instance, 
                              max_generation = 100000, 
                              local_search = False, 
                              p = 30, 
                              cross_rate = 0.8, 
                              mute_rate = 0.15, 
                              mute_method = 'reverse')
        ig.eval(40000)
        size_n.append (instance.shape[0])
        size_m.append (instance.shape[1])
        err_up.append ((ig.best_pop.best_makespan - up[index]) / up[index])
        err_low.append ((ig.best_pop.best_makespan - low[index]) / low[index])
        print (index, ig.iterations)
        #print("Best makespan", ig.best_solver.makespan, ig.iterations)
        #print("Job permutation:", ig.best_solver.permutation)
    ERR_up = np.array (err_up)
    sns.distplot (err_up, fit = norm)
    (mu, sigma) = norm.fit (ERR_up)
    print ('\n mu = {:.2f} and sigma = {:.2f}\n'.format (mu, sigma))
    plt.legend (['Normal dist. ($\mu$ {:.2f} and $\sigma=$ {:.2f})'.format (mu, sigma)], loc = 'best')
    plt.ylabel ('Frequency', fontproperties='SimHei')
    plt.title ('Error of UP', fontproperties='SimHei')

    fig = plt.figure()
    res = stats.probplot (ERR_up, plot = plt)
    plt.show ()
    ERR_low = np.array (err_low)
    sns.distplot (ERR_low, fit = norm)
    (mu, sigma) = norm.fit (ERR_low)
    print ('\n mu = {:.2f} and sigma = {:.2f}\n'.format (mu, sigma))
    plt.legend (['Normal dist. ($\mu$ {:.2f} and $\sigma=$ {:.2f})'.format (mu, sigma)], loc = 'best')
    plt.ylabel ('Frequency', fontproperties='SimHei')
    plt.title ('Error of LOW', fontproperties='SimHei')

    fig = plt.figure()
    res = stats.probplot (ERR_low, plot = plt)
    plt.show ()
    print (len(err_up), len(err_low), len(size_n), len(size_m))
    data = pd.DataFrame ({'err_up': err_up, 'err_low' : err_low, 'n' : size_n, 'm' : size_m})
    data.to_csv ('results/GA_NOLS_vrf_small_MG1e5_P30_CR80_MR15_RT40S.csv')

# %%
import math
import random
import numpy as np
from datetime import datetime, timedelta
from solver import Solver
from population import Population
import localSearch
from GeneticAlgorithm import GeneticAlgorithm
from Climb import Climb
from SimulatedAnnealing import SimulatedAnnealing
from chromes import initializeChromes, selectChromes, crossChromes, muteChromes
import loadData
import NEH
import selection
import chromes
from matplotlib import pyplot as plt
import seaborn as sns
import pandas as pd
from scipy import stats
from scipy.stats import norm, skew
color = sns.color_palette()
sns.set_style ('darkgrid')
rc = {'font.sans-serif': 'SimHei',
          'axes.unicode_minus': False}
import warnings
def ignore_warn(*args, **kwargs):
    pass
warnings.warn = ignore_warn
err_up = list()
err_low = list()
size_n = list()
size_m = list()
def ex6():
    instances, up , low = loadData.dataLoading ("vrf_large")
    for index, instance in enumerate(instances):
        ig = GeneticAlgorithm(data = instance, 
                              max_generation = 100000, 
                              local_search = False, 
                              p = 30, 
                              cross_rate = 0.8, 
                              mute_rate = 0.15, 
                              mute_method = 'reverse')
        ig.eval(40000)
        size_n.append (instance.shape[0])
        size_m.append (instance.shape[1])
        err_up.append ((ig.best_pop.best_makespan - up[index]) / up[index])
        err_low.append ((ig.best_pop.best_makespan - low[index]) / low[index])
        print (index, ig.iterations)
        #print("Best makespan", ig.best_solver.makespan, ig.iterations)
        #print("Job permutation:", ig.best_solver.permutation)
    ERR_up = np.array (err_up)
    sns.distplot (err_up, fit = norm)
    (mu, sigma) = norm.fit (ERR_up)
    print ('\n mu = {:.2f} and sigma = {:.2f}\n'.format (mu, sigma))
    plt.legend (['Normal dist. ($\mu$ {:.2f} and $\sigma=$ {:.2f})'.format (mu, sigma)], loc = 'best')
    plt.ylabel ('Frequency', fontproperties='SimHei')
    plt.title ('Error of UP', fontproperties='SimHei')

    fig = plt.figure()
    res = stats.probplot (ERR_up, plot = plt)
    plt.show ()
    ERR_low = np.array (err_low)
    sns.distplot (ERR_low, fit = norm)
    (mu, sigma) = norm.fit (ERR_low)
    print ('\n mu = {:.2f} and sigma = {:.2f}\n'.format (mu, sigma))
    plt.legend (['Normal dist. ($\mu$ {:.2f} and $\sigma=$ {:.2f})'.format (mu, sigma)], loc = 'best')
    plt.ylabel ('Frequency', fontproperties='SimHei')
    plt.title ('Error of LOW', fontproperties='SimHei')

    fig = plt.figure()
    res = stats.probplot (ERR_low, plot = plt)
    plt.show ()
    print (len(err_up), len(err_low), len(size_n), len(size_m))
    data = pd.DataFrame ({'err_up': err_up, 'err_low' : err_low, 'n' : size_n, 'm' : size_m})
    data.to_csv ('results/GA_NOLS_vrf_large_MG1e5_P30_CR80_MR15_RT40S.csv')

# %%
import math
import random
import numpy as np
from datetime import datetime, timedelta
from solver import Solver
from population import Population
import localSearch
from GeneticAlgorithm import GeneticAlgorithm
from Climb import Climb
from SimulatedAnnealing import SimulatedAnnealing
from chromes import initializeChromes, selectChromes, crossChromes, muteChromes
import loadData
import NEH
import selection
import chromes
from matplotlib import pyplot as plt
import seaborn as sns
import pandas as pd
from scipy import stats
from scipy.stats import norm, skew
color = sns.color_palette()
sns.set_style ('darkgrid')
rc = {'font.sans-serif': 'SimHei',
          'axes.unicode_minus': False}
import warnings
def ignore_warn(*args, **kwargs):
    pass
warnings.warn = ignore_warn
err_up = list()
err_low = list()
size_n = list()
size_m = list()
def ex7():
    instances, up , low = loadData.dataLoading ("vrf_large")
    for index, instance in enumerate(instances):
        ig = Climb(data = instance) 
        ig.tie_breaking = True
        ig.local_search = False
        ig.max_loop = 100000
        ig.eval(2000)
        size_n.append (instance.shape[0])
        size_m.append (instance.shape[1])
        err_up.append ((ig.best_solver.makespan - up[index]) / up[index])
        err_low.append ((ig.best_solver.makespan - low[index]) / low[index])
        print (index, ig.iterations)
        #print("Best makespan", ig.best_solver.makespan, ig.iterations)
        #print("Job permutation:", ig.best_solver.permutation)
    ERR_up = np.array (err_up)
    sns.distplot (err_up, fit = norm)
    (mu, sigma) = norm.fit (ERR_up)
    print ('\n mu = {:.2f} and sigma = {:.2f}\n'.format (mu, sigma))
    plt.legend (['Normal dist. ($\mu$ {:.2f} and $\sigma=$ {:.2f})'.format (mu, sigma)], loc = 'best')
    plt.ylabel ('Frequency', fontproperties='SimHei')
    plt.title ('Error of UP', fontproperties='SimHei')

    fig = plt.figure()
    res = stats.probplot (ERR_up, plot = plt)
    plt.show ()
    ERR_low = np.array (err_low)
    sns.distplot (ERR_low, fit = norm)
    (mu, sigma) = norm.fit (ERR_low)
    print ('\n mu = {:.2f} and sigma = {:.2f}\n'.format (mu, sigma))
    plt.legend (['Normal dist. ($\mu$ {:.2f} and $\sigma=$ {:.2f})'.format (mu, sigma)], loc = 'best')
    plt.ylabel ('Frequency', fontproperties='SimHei')
    plt.title ('Error of LOW', fontproperties='SimHei')

    fig = plt.figure()
    res = stats.probplot (ERR_low, plot = plt)
    plt.show ()
    print (len(err_up), len(err_low), len(size_n), len(size_m))
    data = pd.DataFrame ({'err_up': err_up, 'err_low' : err_low, 'n' : size_n, 'm' : size_m})
    data.to_csv ('results/Climb_NOLS_vrf_large_MG1e5_P30_CR80_MR15_RT20S.csv')

# %%
import math
import random
import numpy as np
from datetime import datetime, timedelta
from solver import Solver
from population import Population
import localSearch
from GeneticAlgorithm import GeneticAlgorithm
from Climb import Climb
from SimulatedAnnealing import SimulatedAnnealing
from chromes import initializeChromes, selectChromes, crossChromes, muteChromes
import loadData
import NEH
import selection
import chromes
from matplotlib import pyplot as plt
import seaborn as sns
import pandas as pd
from scipy import stats
from scipy.stats import norm, skew
color = sns.color_palette()
sns.set_style ('darkgrid')
rc = {'font.sans-serif': 'SimHei',
          'axes.unicode_minus': False}
import warnings
def ignore_warn(*args, **kwargs):
    pass
warnings.warn = ignore_warn
err_up = list()
err_low = list()
size_n = list()
size_m = list()
def ex8():
    instances, up , low = loadData.dataLoading ("vrf_small")
    for index, instance in enumerate(instances):
        ig = Climb(data = instance) 
        ig.tie_breaking = True
        ig.local_search = False
        ig.max_loop = 100000
        ig.eval(2000)
        size_n.append (instance.shape[0])
        size_m.append (instance.shape[1])
        err_up.append ((ig.best_solver.makespan - up[index]) / up[index])
        err_low.append ((ig.best_solver.makespan - low[index]) / low[index])
        print (index, ig.iterations)
        #print("Best makespan", ig.best_solver.makespan, ig.iterations)
        #print("Job permutation:", ig.best_solver.permutation)
    ERR_up = np.array (err_up)
    sns.distplot (err_up, fit = norm)
    (mu, sigma) = norm.fit (ERR_up)
    print ('\n mu = {:.2f} and sigma = {:.2f}\n'.format (mu, sigma))
    plt.legend (['Normal dist. ($\mu$ {:.2f} and $\sigma=$ {:.2f})'.format (mu, sigma)], loc = 'best')
    plt.ylabel ('Frequency', fontproperties='SimHei')
    plt.title ('Error of UP', fontproperties='SimHei')

    fig = plt.figure()
    res = stats.probplot (ERR_up, plot = plt)
    plt.show ()
    ERR_low = np.array (err_low)
    sns.distplot (ERR_low, fit = norm)
    (mu, sigma) = norm.fit (ERR_low)
    print ('\n mu = {:.2f} and sigma = {:.2f}\n'.format (mu, sigma))
    plt.legend (['Normal dist. ($\mu$ {:.2f} and $\sigma=$ {:.2f})'.format (mu, sigma)], loc = 'best')
    plt.ylabel ('Frequency', fontproperties='SimHei')
    plt.title ('Error of LOW', fontproperties='SimHei')

    fig = plt.figure()
    res = stats.probplot (ERR_low, plot = plt)
    plt.show ()
    print (len(err_up), len(err_low), len(size_n), len(size_m))
    data = pd.DataFrame ({'err_up': err_up, 'err_low' : err_low, 'n' : size_n, 'm' : size_m})
    data.to_csv ('results/Climb_NOLS_vrf_small_MG1e5_P30_CR80_MR15_RT20S.csv')

# %%
ex5()
ex6()
ex7()
ex8()

# %%
data1 = pd.read_csv ("results/GA_NOLS_vrf_large_MG1e5_P30_CR80_MR15_RT40S.csv")

# %%
data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 480 entries, 0 to 479
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  480 non-null    int64
#  1   err_up      480 non-null    float64
#  2   err_low     480 non-null    float64
#  3   n           480 non-null    int64
#  4   m           480 non-null    int64
# dtypes: float64(2), int64(3)
# memory usage: 18.9 KB

# %%
data = data1.drop (1)

# %%
data = data1.drop (range(240))

# %%
data.rename (index = lambda s : s - 240)
# Out:
#      Unnamed: 0    err_up   err_low    n   m
# 0           240  0.152630  0.252235  100  20
# 1           241  0.182913  0.260666  100  20
# 2           242  0.161909  0.255483  100  20
# 3           243  0.169285  0.263906  100  20
# 4           244  0.163811  0.256787  100  20
# ..          ...       ...       ...  ...  ..
# 235         475  0.130385  0.210808  800  60
# 236         476  0.130997  0.215043  800  60
# 237         477  0.130897  0.212350  800  60
# 238         478  0.126329  0.207274  800  60
# 239         479  0.126219  0.207483  800  60
#
# [240 rows x 5 columns]

# %%
data.to_csv ("results/GA_NOLS_vrf_large_MG1e5_P30_CR80_MR15_RT40S_b.csv")

# %%
data2 = pd.read_csv ("results/Climb_vrf_small_ML1e5_RT40S.csv")

# %%
data = data2.drop (range(720))

# %%
data.rename (index = lambda s : s - 720, inplace = True)

# %%
data.drop (['Unnamed: 0'], axis = 1, inplace = True)

# %%
data
# Out:
#        err_up   err_low    n   m
# 0    0.012162  0.085196  800  60
# 1    0.001823  0.378921   10  10
# 2   -0.001820  0.318510   10  10
# 3    0.000000  0.356213   10  10
# 4    0.000000  0.352587   10  10
# ..        ...       ...  ...  ..
# 236  0.000000  0.018477   60   5
# 237  0.000000  0.016024   60   5
# 238  0.000000  0.015936   60   5
# 239  0.000000  0.015357   60   5
# 240  0.000000  0.015290   60   5
#
# [241 rows x 4 columns]

# %%
data.to_csv ("results/Climb_vrf_small_ML1e5_RT40S.csv")

# %%
data.drop (['Unnamed: 0'], axis = 1, inplace = True)

# %%
data = pd.read_csv ("results/GA_NOLS_vrf_large_MG1e5_P30_CR80_MR15_RT40S_fb.csv")

# %%
data.rename (index = lambda s : s - 240, inplace = True)

# %%
data.rename (index = lambda s : s + 240, inplace = True)

# %%
data.drop (['Unnamed: 0', 'Unnamed: 0.1'], axis = 1, inplace = True)

# %%
# Out:
#        err_up   err_low    n   m
# 0    0.152630  0.252235  100  20
# 1    0.182913  0.260666  100  20
# 2    0.161909  0.255483  100  20
# 3    0.169285  0.263906  100  20
# 4    0.163811  0.256787  100  20
# ..        ...       ...  ...  ..
# 235  0.130385  0.210808  800  60
# 236  0.130997  0.215043  800  60
# 237  0.130897  0.212350  800  60
# 238  0.126329  0.207274  800  60
# 239  0.126219  0.207483  800  60
#
# [240 rows x 4 columns]

# %%
import math
import random
import numpy as np
from datetime import datetime, timedelta
from solver import Solver
from population import Population
import localSearch
from GeneticAlgorithm import GeneticAlgorithm
from Climb import Climb
from SimulatedAnnealing import SimulatedAnnealing
from chromes import initializeChromes, selectChromes, crossChromes, muteChromes
import loadData
import NEH
from NEH import NawazEnscoreHam
import selection
import chromes
from matplotlib import pyplot as plt
import seaborn as sns
import pandas as pd
from scipy import stats
from scipy.stats import norm, skew
color = sns.color_palette()
sns.set_style ('darkgrid')
rc = {'font.sans-serif': 'SimHei',
          'axes.unicode_minus': False}
import warnings
def ignore_warn(*args, **kwargs):
    pass
warnings.warn = ignore_warn
err_up = list()
err_low = list()
size_n = list()
size_m = list()
def ex2():
    instances, up , low = loadData.dataLoading ("rec")
    for index, instance in enumerate(instances):
        ig = NawazEnscoreHam (instance, tie_breaking = True)
        ig.eval()
        size_n.append (instance.shape[0])
        size_m.append (instance.shape[1])
        err_up.append ((ig.solver.makespan - up[index]) / up[index])
        err_low.append ((ig.solver.makespan - low[index]) / low[index])
        print (index, ig.iterations)
        #print("Best makespan", ig.best_solver.makespan, ig.iterations)
        #print("Job permutation:", ig.best_solver.permutation)
    ERR_up = np.array (err_up)
    sns.distplot (err_up, fit = norm)
    (mu, sigma) = norm.fit (ERR_up)
    print ('\n mu = {:.2f} and sigma = {:.2f}\n'.format (mu, sigma))
    plt.legend (['Normal dist. ($\mu$ {:.2f} and $\sigma=$ {:.2f})'.format (mu, sigma)], loc = 'best')
    plt.ylabel ('Frequency', fontproperties='SimHei')
    plt.title ('Error of UP', fontproperties='SimHei')

    fig = plt.figure()
    res = stats.probplot (ERR_up, plot = plt)
    plt.show ()
    ERR_low = np.array (err_low)
    sns.distplot (ERR_low, fit = norm)
    (mu, sigma) = norm.fit (ERR_low)
    print ('\n mu = {:.2f} and sigma = {:.2f}\n'.format (mu, sigma))
    plt.legend (['Normal dist. ($\mu$ {:.2f} and $\sigma=$ {:.2f})'.format (mu, sigma)], loc = 'best')
    plt.ylabel ('Frequency', fontproperties='SimHei')
    plt.title ('Error of LOW', fontproperties='SimHei')

    fig = plt.figure()
    res = stats.probplot (ERR_low, plot = plt)
    plt.show ()
    print (len(err_up), len(err_low), len(size_n), len(size_m))
    data = pd.DataFrame ({'err_up': err_up, 'err_low' : err_low, 'n' : size_n, 'm' : size_m})
    data.to_csv ('results/NEH_rec.csv')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_24520/880372997.py in <module>
#       3 import numpy as np
#       4 from datetime import datetime, timedelta
# ----> 5 from solver import Solver
#       6 from population import Population
#       7 import localSearch
#
# ModuleNotFoundError: No module named 'solver'

# %%
ex2()
